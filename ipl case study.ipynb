# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
A=pd.read_csv("data\ipl data.csv")

# %%
A
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# # read ipl.csv file and print first 5 records

# %%
A.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # check total number of columns,entries note down your findings

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %% [raw]
# Analysis:-IN this data set there are 636 rows and 18 columns
#           There are 12 categorical columns and 6 numerical columns
#           There is null value in 5 columns.
#           umpire 3 column has highest number of null values

# %% [markdown]
# # find null values

# %%
A.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %% [raw]
# #drop null values of city , winner ,player_of_match,umpire1,umpire2 column

# %% [markdown]
# # drop umpire3 column as it contains more than 75% of null values

# %%
A.drop(["umpire3"],axis=1,inplace=True)

# %%
A
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# # drop null values of city , winner ,player_of_match,umpire1,umpire2 column.

# %%
A.dropna()
# Out:
#       id  season       city        date                   team1  \
# 0      1    2017  Hyderabad  2017-04-05     Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06          Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3      4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5      6    2017  Hyderabad  2017-04-09           Gujarat Lions
# ..   ...     ...        ...         ...                     ...
# 631  632    2016     Raipur  2016-05-22        Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24           Gujarat Lions
# 633  634    2016      Delhi  2016-05-25     Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27           Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29     Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %% [markdown]
# # which city hosted most number of matches?
# #draw bar plot and write down your insights

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\n\t\t\t\t~~Mumbai hosted most number of matches and bloemfontein has hosted least number of matches") 
print(("*")*120)
B=A.groupby("city")["id"].count().sort_values(ascending=False).plot(kind="bar")
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
#
# 				~~Mumbai hosted most number of matches and bloemfontein has hosted least number of matches
# ************************************************************************************************************************

# %% [markdown]
# # find all venue of mumbai city

# %%
C=A.groupby("city")

# %%
D=C.get_group("Mumbai")["venue"].value_counts()

# %%
print(D)
# Out:
# Wankhede Stadium              57
# Dr DY Patil Sports Academy    17
# Brabourne Stadium             11
# Name: venue, dtype: int64

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\n\t\t\t\t~~ Mumbai has 3 venues namely Wankhede stadium, DY patil, Brabourne stadium") 
print(("*")*120)
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
#
# 				~~ Mumbai has 3 venues namely Wankhede stadium, DY patil, Brabourne stadium
# ************************************************************************************************************************

# %% [markdown]
# # now compare in which venue of mumbai most number of matches played (draw bar plot and write down insights)

# %%
E=C.get_group("Mumbai")

# %%
E
# Out:
#       id  season    city        date                        team1  \
# 6      7    2017  Mumbai  2017-04-09        Kolkata Knight Riders
# 9     10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15    16    2017  Mumbai  2017-04-16                Gujarat Lions
# 23    24    2017  Mumbai  2017-04-22               Mumbai Indians
# 27    28    2017  Mumbai  2017-04-24       Rising Pune Supergiant
# ..   ...     ...     ...         ...                          ...
# 572  573    2015  Mumbai  2015-05-19               Mumbai Indians
# 576  577    2016  Mumbai  2016-04-09               Mumbai Indians
# 584  585    2016  Mumbai  2016-04-16               Mumbai Indians
# 589  590    2016  Mumbai  2016-04-20  Royal Challengers Bangalore
# 599  600    2016  Mumbai  2016-04-28        Kolkata Knight Riders
#
#                        team2       toss_winner toss_decision  result  \
# 6             Mumbai Indians    Mumbai Indians         field  normal
# ...

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\n~~ From the plot we can say Wankhede has hosted most number of matches in mumbai followed by Dy patil and Brabourne stadium.") 
print(("*")*120)
F=E.groupby("venue")["id"].count().sort_values(ascending=False).plot(kind="bar")
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
#
# ~~ From the plot we can say Wankhede has hosted most number of matches in mumbai followed by Dy patil and Brabourne stadium.
# ************************************************************************************************************************

# %% [markdown]
# # what is the preferred choice after winning a toss in mumbai

# %%
G=E.groupby("toss_decision")["id"].count()

# %%
G
# Out:
# toss_decision
# bat      34
# field    51
# Name: id, dtype: int64

# %%
#graphical representation of above question

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\n\t\t\t\t~~ 60% of teams preferr to bowl first after winning toss in Mumbai.") 
print(("*")*120)
G=E.groupby("toss_decision")["id"].count().plot(kind="pie",autopct="%1.2f%%")
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
#
# 				~~ 60% of teams preferr to bowl first after winning toss in Mumbai.
# ************************************************************************************************************************

# %% [markdown]
# # which team won most number of toss

# %%
H=A.groupby("toss_winner")["id"].count().sort_values(ascending=False)

# %%
H
# Out:
# toss_winner
# Mumbai Indians                 85
# Kolkata Knight Riders          78
# Delhi Daredevils               72
# Royal Challengers Bangalore    70
# Kings XI Punjab                68
# Chennai Super Kings            66
# Rajasthan Royals               63
# Deccan Chargers                43
# Sunrisers Hyderabad            35
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: id, dtype: int64

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\n\t\t\t\t~~ Mumbai indians is the most successfull team in terms of winning toss.") 
print(("*")*120)
H=A.groupby("toss_winner")["id"].count().sort_values(ascending=False).plot(kind="bar")
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
#
# 				~~ Mumbai indians is the most successfull team in terms of winning toss.
# ************************************************************************************************************************

# %% [markdown]
# # find what mumbai indians preferred after winning a toss?

# %%
H1=A.groupby("toss_winner")

# %%
H1

# %%
H2=H1.get_group("Mumbai Indians")["toss_decision"].value_counts()

# %%
H2
# Out:
# field    45
# bat      40
# Name: toss_decision, dtype: int64

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\n\t\t\t\t~~ MI choose to bat and bowl almost equal number of times after winning toss.") 
print(("*")*120)
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
#
# 				~~ MI choose to bat and bowl almost equal number of times after winning toss.
# ************************************************************************************************************************

# %% [markdown]
# # head to head winning count of Mumbai Indians vs Chennai Super Kings

# %%
A[((A["team1"]=="Mumbai Indians")|(A["team1"]=="Chennai Super Kings"))&((A["team2"]=="Mumbai Indians")|(A["team2"]=="Chennai Super Kings"))]["winner"].value_counts()
# Out:
# Mumbai Indians         12
# Chennai Super Kings    10
# Name: winner, dtype: int64

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\n\t\t\t\t~~ IN head to head rivalry MI is 2 wins ahead of CSK") 
print(("*")*120)
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
#
# 				~~ IN head to head rivalry MI is 2 wins ahead of CSK
# ************************************************************************************************************************

# %% [markdown]
# # Which team won most of the matches in mumbai?

# %%
I=C.get_group("Mumbai")["winner"].value_counts()

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\n\t\t\t\t~~ MI won most number of matches in mumbai") 
print(("*")*120)
I
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
#
# 				~~ MI won most number of matches in mumbai
# ************************************************************************************************************************
# Mumbai Indians                 45
# Chennai Super Kings             8
# Kings XI Punjab                 5
# Royal Challengers Bangalore     5
# Rajasthan Royals                5
# Deccan Chargers                 3
# Kolkata Knight Riders           3
# Pune Warriors                   3
# Rising Pune Supergiant          2
# Delhi Daredevils                2
# Kochi Tuskers Kerala            1
# Sunrisers Hyderabad             1
# Rising Pune Supergiants         1
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %% [markdown]
# # how many times each team won the toss and won the match

# %%
B=A[(A['toss_winner'] == A['winner'])]

# %%
B
# Out:
#       id  season       city        date                        team1  \
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# ..   ...     ...        ...         ...                          ...
# 629  630    2016     Kanpur  2016-05-21               Mumbai Indians
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
B.groupby("winner")["id"].count()
# Out:
# winner
# Chennai Super Kings            42
# Deccan Chargers                19
# Delhi Daredevils               33
# Gujarat Lions                  10
# Kings XI Punjab                28
# Kochi Tuskers Kerala            4
# Kolkata Knight Riders          44
# Mumbai Indians                 48
# Pune Warriors                   3
# Rajasthan Royals               34
# Rising Pune Supergiant          5
# Rising Pune Supergiants         3
# Royal Challengers Bangalore    35
# Sunrisers Hyderabad            17
# Name: id, dtype: int64

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\n~~ MI ,kkr and csk has high number of wins after winning a toss, so we can say they took right decision after winning toss") 
print(("*")*120)
B.groupby("winner")["id"].count().sort_values(ascending=False).plot(kind="bar")
plt.show()
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
#
# ~~ MI ,kkr and csk has high number of wins after winning a toss, so we can say they took right decision after winning toss
# ************************************************************************************************************************

# %% [markdown]
# # how many times each team won the toss and won the match in mumbai

# %%
Q=A[(A["toss_winner"]==A["winner"])&(A["city"]=="Mumbai")]

# %%
Q
# Out:
#       id  season    city        date                        team1  \
# 6      7    2017  Mumbai  2017-04-09        Kolkata Knight Riders
# 9     10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15    16    2017  Mumbai  2017-04-16                Gujarat Lions
# 71    72    2008  Mumbai  2008-04-27               Mumbai Indians
# 85    86    2008  Mumbai  2008-05-07             Rajasthan Royals
# 95    96    2008  Mumbai  2008-05-14          Chennai Super Kings
# 98    99    2008  Mumbai  2008-05-16        Kolkata Knight Riders
# 116  117    2008  Mumbai  2008-06-01          Chennai Super Kings
# 175  176    2010  Mumbai  2010-03-13               Mumbai Indians
# 193  194    2010  Mumbai  2010-03-25          Chennai Super Kings
# 200  201    2010  Mumbai  2010-03-30              Kings XI Punjab
# 206  207    2010  Mumbai  2010-04-03               Mumbai Indians
# 220  221    2010  Mumbai  2010-04-13               Mumbai Indians
# ...

# %%
Q1=Q["winner"].value_counts()

# %%
Q1
# Out:
# Mumbai Indians                 26
# Chennai Super Kings             5
# Deccan Chargers                 3
# Rajasthan Royals                2
# Delhi Daredevils                2
# Royal Challengers Bangalore     2
# Kochi Tuskers Kerala            1
# Kolkata Knight Riders           1
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\n\t\t\t\t~~ MI won most number of matches after winning toss in mumbai") 
print(("*")*120)
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
#
# 				~~ MI won most number of matches after winning toss in mumbai
# ************************************************************************************************************************

# %% [markdown]
# # which venue hosted most number of matches

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\n\t\t\t\t~~ M Chinnaswamy stadium hosted most number of matches in ipl history") 
print(("*")*120)
A.groupby("venue")["id"].count().sort_values(ascending=False).plot(kind="bar")
plt.show()
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
#
# 				~~ M Chinnaswamy stadium hosted most number of matches in ipl history
# ************************************************************************************************************************

# %%
A
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# # find how many matches chennai super kings played at M Chinnaswamy stadium?

# %%
M=A.groupby("venue")

# %%
N=M.get_group("M Chinnaswamy Stadium")
N
# Out:
#       id  season       city        date                        team1  \
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 11    12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 16    17    2017  Bangalore  2017-04-16       Rising Pune Supergiant
# 29    30    2017  Bangalore  2017-04-27  Royal Challengers Bangalore
# 41    42    2017  Bangalore  2017-05-05              Kings XI Punjab
# ..   ...     ...        ...         ...                          ...
# 616  617    2016  Bangalore  2016-05-11  Royal Challengers Bangalore
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
# 625  626    2016  Bangalore  2016-05-18  Royal Challengers Bangalore
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
N1=N[(N["team1"]=="Chennai Super Kings")|(N["team2"]=="Chennai Super Kings")]["id"].count()

# %%
N1
# Out:
# 7

# %% [markdown]
# # who won most matches at M Chinnaswamy stadium?

# %%
print(("*")*120)
print("\t\t\t\t**************ANALYSIS***************\n\n\t\t\t\t~~ RCB Won most number of matches in M Chinnaswamy stadium. ") 
print(("*")*120)
A[A["venue"]=="M Chinnaswamy Stadium"]["winner"].value_counts()
# Out:
# ************************************************************************************************************************
# 				**************ANALYSIS***************
#
# 				~~ RCB Won most number of matches in M Chinnaswamy stadium.
# ************************************************************************************************************************
# Royal Challengers Bangalore    30
# Mumbai Indians                  8
# Kolkata Knight Riders           6
# Kings XI Punjab                 5
# Chennai Super Kings             4
# Rajasthan Royals                3
# Delhi Daredevils                3
# Sunrisers Hyderabad             2
# Rising Pune Supergiant          1
# Gujarat Lions                   1
# Deccan Chargers                 1
# Name: winner, dtype: int64

# %% [raw]
# #year wise analysis
# #matches played in each year
# #lets analyse ipl season held in 2013
# #extract all the details of 2013 season
# #here we will create yearwise groups (hint: use groupby() function)

# %%
A[A["season"]==2013]
# Out:
#       id  season       city        date                        team1  \
# 381  382    2013    Kolkata  2013-04-03             Delhi Daredevils
# 382  383    2013  Bangalore  2013-04-04  Royal Challengers Bangalore
# 383  384    2013  Hyderabad  2013-04-05          Sunrisers Hyderabad
# 384  385    2013      Delhi  2013-04-06             Rajasthan Royals
# 385  386    2013    Chennai  2013-04-06               Mumbai Indians
# ..   ...     ...        ...         ...                          ...
# 452  453    2013  Hyderabad  2013-05-19        Kolkata Knight Riders
# 453  454    2013      Delhi  2013-05-21          Chennai Super Kings
# 454  455    2013      Delhi  2013-05-22          Sunrisers Hyderabad
# 455  456    2013    Kolkata  2013-05-24             Rajasthan Royals
# 456  457    2013    Kolkata  2013-05-26               Mumbai Indians
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %% [markdown]
# # which city hosted most number of matches in 2013

# %%
A[A["season"]==2013]["city"].value_counts()
# Out:
# Kolkata       8
# Bangalore     8
# Hyderabad     8
# Delhi         8
# Chennai       8
# Pune          8
# Jaipur        8
# Mumbai        8
# Chandigarh    6
# Dharamsala    2
# Raipur        2
# Ranchi        2
# Name: city, dtype: int64
